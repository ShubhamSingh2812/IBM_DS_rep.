# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **SHUBHAM KUMAR SINGH**

# %% [markdown]
# Currently i am working as a quality assurance engineer for an australian startup.

# %% [markdown]
# *I am intrested in data science because in todays world data is a crucial and important aspect for all kind of businessess. Using data science we can predict and be prepared and plan for better future.*

# %% [markdown]
# ### Calculating area of a square

# %%
a = 10
b = 20
c = a * b
print("area of square:", c)
# Out:
# area of square: 200

# %% [markdown]
# **Days in a week**
# 1. Sunday
# 2. Monday
# 3. Tuesday
# 4. Wednesday
# 5. Thursday
# 6. Friday
# 7. Saturday

# %% [markdown]
# [Youtube Homepage](https://www.youtube.com/)

# %% [markdown]
# | Name | Age | Height |
# |------|-----|--------|
# | Tom  | 20  | 5'10" |
# | Dick | 21  | 5'11" |
# | Harry| 22  | 6'0"  |
